# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('f4.jpg',0)
# global thresholding
ret1,th1 = cv2.threshold(img,200,255,cv2.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv2.GaussianBlur(img,(1,1),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# plot all the images and their histograms

images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])

    
plt.show()

# %%
import cv2
import numpy as np
img = cv2.imread('f4.jpg',0)
# global thresholding
ret3,th3 = cv2.threshold(blur,100,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
# plot all the images and their histograms

for i in range(2):
    plt.imshow(images[i*3+2],'gray')

plt.xticks([])
plt.yticks([])

 
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1 = cv2.imread('f4.jpg',1)
img2 = cv2.imread('f3.png',1)

img2 = cv2.resize(img2,(750,600))
img1 = cv2.resize(img1,(750,600))

dst = cv2.multiply(img1/255,img2/255)

res = np.hstack([dst])

plt.imshow(res)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1 = cv2.imread('f4.jpg',1)
img2 = cv2.imread('f5.png',1)

img2 = cv2.resize(img2,(750,600))
img1 = cv2.resize(img1,(750,600))

dst = cv2.multiply(img1/255,img2/255)

res = np.hstack([dst])

plt.imshow(res)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('f6.png',1)
img2 = cv2.imread('f3.png',1)

kernel = np.ones((6,6),np.float)/25
dst = cv2.filter2D(img,-1,kernel)

dst1 = cv2.add(dst/255,img2/255)
res = np.hstack([dst])

plt.subplot(1,2,1),plt.imshow(dst)
plt.xticks([]), plt.yticks([])

plt.subplot(1,2,2),plt.imshow(dst1)
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-44-3a2fac4e2c12> in <module>()
#       9 dst = cv2.filter2D(img,-1,kernel)
#      10
# ---> 11 dst1 = cv2.add(dst/255,img2/255)
#      12 res = np.hstack([dst])
#      13
#
# error: C:\bld\opencv_1498171314629\work\opencv-3.2.0\modules\core\src\arithm.cpp:659: error: (-209) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function cv::arithm_op

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('f6.png',1)
img2 = cv2.imread('f5.png',1)

kernel = np.ones((6,6),np.float)/25
dst = cv2.filter2D(img,-1,kernel)

dst1 = cv2.add(dst/255,img2/255)
res = np.hstack([dst])



plt.subplot(1,1,1),plt.imshow(dst1)
plt.xticks([]), plt.yticks([])
plt.show()
