# %% [markdown]
# # Histograms

# %% [markdown]
# histogram is a graphical representation showing how frequently various color values(intensity value) occur in the image.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt #loads up the pyplot library


img = cv2.imread("images/img1.jpg",0)# read the image as grayscale 


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.hist(img.ravel(),256,[0,256])#the first parameter to the function is the list of images to process.
#The next parameter is the histogram size, or the number of “bins” to use for the histogram #256 >> grayscale image.
#final parameter is the range of values each of the pixels in the image can have. Assuming 24-bit color, each channel
#has values between 0 and 255.

plt.title('histogram')
plt.xticks([]), plt.yticks([])  
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.show()

# %% [raw]
# Histograms Equalization

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt #loads up the pyplot library


img = cv2.imread('images/img1.jpg',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-sideplt.xticks([]), plt.yticks([])  

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.hist(img.ravel(),256,[0,256]) ,plt.title('histogram')
plt.xticks([]), plt.yticks([]) 
plt.show()

# %% [markdown]
# Work contrast stretches
# Because low contrast
# And for to improve it to high contrast
# So that I can be work on image.
